# %% [markdown]
# <a href="https://colab.research.google.com/github/Sourav61/Girlscript-ML_now/blob/main/02_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd'/content/drive/MyDrive/student-mat.csv'
# Out:
# [Errno 20] Not a directory: '/content/drive/MyDrive/student-mat.csv'
# /content

# %%
import pandas as pd #working with csv or excel files
import numpy as np #working with numbers/ arrays/ tensors
import tensorflow as tf #framework
from tensorflow import keras #API / library 
import os #using os commands between the python language

# %%
df = pd.read_csv("student-mat.csv",sep=';')
df
# Out:
#     school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 0       GP   F   18       U     GT3       A  ...     1       3        6   5   6   6
# 1       GP   F   17       U     GT3       T  ...     1       3        4   5   5   6
# 2       GP   F   15       U     LE3       T  ...     3       3       10   7   8  10
# 3       GP   F   15       U     GT3       T  ...     1       5        2  15  14  15
# 4       GP   F   16       U     GT3       T  ...     2       5        4   6  10  10
# ..     ...  ..  ...     ...     ...     ...  ...   ...     ...      ...  ..  ..  ..
# 390     MS   M   20       U     LE3       A  ...     5       4       11   9   9   9
# 391     MS   M   17       U     LE3       T  ...     4       2        3  14  16  16
# 392     MS   M   21       R     GT3       T  ...     3       3        3  10   8   7
# 393     MS   M   18       R     LE3       T  ...     4       5        0  11  12  10
# ...

# %%
df.head(10)
# Out:
#   school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 0     GP   F   18       U     GT3       A  ...     1       3        6   5   6   6
# 1     GP   F   17       U     GT3       T  ...     1       3        4   5   5   6
# 2     GP   F   15       U     LE3       T  ...     3       3       10   7   8  10
# 3     GP   F   15       U     GT3       T  ...     1       5        2  15  14  15
# 4     GP   F   16       U     GT3       T  ...     2       5        4   6  10  10
# 5     GP   M   16       U     LE3       T  ...     2       5       10  15  15  15
# 6     GP   M   16       U     LE3       T  ...     1       3        0  12  12  11
# 7     GP   F   17       U     GT3       A  ...     1       1        6   6   5   6
# 8     GP   M   15       U     LE3       A  ...     1       1        0  16  18  19
# 9     GP   M   15       U     GT3       T  ...     1       5        0  14  15  15
#
# [10 rows x 33 columns]

# %%
df.tail(10)
# Out:
#     school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 385     MS   F   18       R     GT3       T  ...     3       4        2  10   9  10
# 386     MS   F   18       R     GT3       T  ...     2       5        7   6   5   6
# 387     MS   F   19       R     GT3       T  ...     2       5        0   7   5   0
# 388     MS   F   18       U     LE3       T  ...     1       1        0   7   9   8
# 389     MS   F   18       U     GT3       T  ...     1       5        0   6   5   0
# 390     MS   M   20       U     LE3       A  ...     5       4       11   9   9   9
# 391     MS   M   17       U     LE3       T  ...     4       2        3  14  16  16
# 392     MS   M   21       R     GT3       T  ...     3       3        3  10   8   7
# 393     MS   M   18       R     LE3       T  ...     4       5        0  11  12  10
# 394     MS   M   19       U     LE3       T  ...     3       5        5   8   9   9
#
# [10 rows x 33 columns]

# %%
print(f'school: {df.school.unique()}')
print(f'sex: {df.sex.unique()}')
print(f'address: {df.address.unique()}')
print(f'Mjob: {df.Mjob.unique()}')
print(f'Fjob: {df.Fjob.unique()}')
print(f'higher: {df.higher.unique()}')
# Out:
# school: ['GP' 'MS']
# sex: ['F' 'M']
# address: ['U' 'R']
# Mjob: ['at_home' 'health' 'other' 'services' 'teacher']
# Fjob: ['teacher' 'other' 'services' 'health' 'at_home']
# higher: ['yes' 'no']
